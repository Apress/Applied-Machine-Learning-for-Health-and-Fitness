# %% [markdown]
# # Chapter 2. Physics of Sports
#
# [*Applied Machine Learning for Health and Fitness*](https://www.apress.com/9781484257715) by Kevin Ashley (Apress, 2020).
#
# [*Video Course*](http://ai-learning.vhx.tv) Need a deep dive? Watch my [*video course*](http://ai-learning.vhx.tv) that complements this book with additional examples and video-walkthroughs.
#
# [*Web Site*](http://activefitness.ai) for research and supplemental materials.
#
#
# Overview
# ========
#
# This chapter provides an overview of physical principles used in modern sport science. In addition to physics, kinesiology and biomechanics, we will also discuss how deep learning can help a sport data scientist, and vice versa, how we can improve our models by knowing a few physics principles. Classical mechanics is a reliable method of movement analysis, and it's a valuable tool if you're planning to build any practical sports machine learning models. In this chapter I'll show how machine learning models, including neural nets and reinforcement learning can be applied to biomechanics.
#
# Mechanics
# =========
#
# -   **Kinematics** describes effects of linear and angular motion: velocity, displacement, acceleration and position.
#
# -   **Kinetics** explains what causes motion: forces, torque and moments.
#
# -   **Work, Energy and Power** are areas where physics helps sports science determine efficiency, calories spend and fatigue.
#
# -   **Skeletal, joint and muscular mechanics** of body tissues, joints and the human frame studies interaction between body parts, stress and strain (this area immediate application to body pose estimation in machine learning).
#
#
# First Law of Motion (Law of Inertia)
# ------------------------------------
#
# $$momentum = mass*\ velocity$$
#
# $$p = mv$$
#
# ![](images/ch2/fig_2-2.PNG)
#
# Figure 2--2 How much force does it take to stop a running football player?
#
# In football, a collision occurs when a tackler stops a running quarterback. Let's say the mass of a quarterback is 100 kg, and his speed 5 m/s. Then the momentum of the quarterback from the first law of motion is 500 kg\*m/s:

# %%
m = 100. # kg
v = 5. # m/s

# Momentum of a football runner
p = m * v
print(f'Momentum {p} kg*m/s')
# Out:
# Momentum 500.0 kg*m/s

# %% [markdown]
# The impulse it takes for a tackler to stop a quarterback is defined by the speed and time of collision. Let's say the tackle occurs to full stop, when the speed is zero, and the time of collision is half a second, then the impulse:

# %%
v1 = 0. # m/s
dt = 0.5 # s

# F=ma or F=m*dv/dt
# F*dt = m*dv

# Impulse to stop a quarterback
dv = v1-v
I = m * dv * dt
print(f'Impulse to stop {I} N*s')
# Out:
# Impulse to stop -250.0 N*s

# %% [markdown]
# Second Law of Motion
# --------------------
#
# Newton's Second Law relates acceleration of a body with an external force F acting on it:
#
# $force = mass*\ acceleration$
#
# $F = ma$
#
# The unit of force is Newtons (N) = kg\*m/s\^2. In our earlier example, the force with which the tackler acts on the quarterback is:

# %%
# Force exherted by tackler on the quarterback
F = m * dv / dt
print(f'Force {F} N')
# Out:
# Force -1000.0 N

# %% [markdown]
# Third Law of Motion
# -------------------
#
# For every action there's an equal and opposite reaction. For example, when a player hits the volleyball, the ball reacts with an equal force on the player.
#
#
# Kinematics: Projectile Motion
# =============================
#
# Sports often involve projectiles: for example, javelin, balls, jumpers etc. Projectile is any object that is released with initial velocity and is subject to forces of gravity and air resistance.
#
# A projectile displacement along horizontal and vertical axes can be determined as:
#
# $${x = v_{0}t\cos\alpha
# }{y = v_{0}t\sin{\alpha + \ \frac{1}{2}gt^{2}}\ }$$
#
# Given release speed *v*, release angle $\alpha$, release height *h,* the range of a projectile can be calculated using the formula:
#
# $$x = \ \frac{v^{2}}{2g}\ \sin{2\alpha}\left( 1 + \ \sqrt{1 + \ \frac{2gh}{v^{2}\sin\alpha}} \right)$$
#
# or, when the projectile is launched at the ground (i.e. h=0),
#
# $$x = \ \frac{v^{2}}{2g}\ \sin{2\alpha}$$
#
# Formula 2-1 Projectile range when launched from the ground
#
# # Project: Calculate and plot a projectile trajectory and find best range and release angle
#
# In this project we'll find an optimal angle of release for an athlete throwing a projectile. Let's assume the release speed of a projectile at 30 m/s and for simplicity it's released at the ground. To test various angles of release, we'll create a list of test angles from 20 to 50 degrees spaced at 5 degrees:

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

g = 9.81 # m/s^2
v = 30 # release speed m/s
angles = np.arange(20, 50, 5)

def projectile(angle, t):
    x = []
    y = []
    for dt in t:
        xt = ((v*dt)*np.cos(angle)) 
        yt = ((v*dt)*np.sin(angle))-((0.5*g)*(dt**2))
        if yt > 0:
            x.append(xt)
            y.append(yt)
    return x,y

# %% [markdown]
# Finally, to plot the results and iterate through test angles finding the best angle, determined by maximum horizontal displacement:

# %%
max_distance = 0
best_angle = None
t = np.linspace(0, 5, 300)
for angle in angles: 
    x,y=projectile(angle*np.pi/180, t)
    distance = x[-1]
    if max_distance < distance:
        max_distance = distance
        best_angle = angle
    plt.plot(x, y, label=r"$\alpha$"+f"={angle:.0f} d={distance:.1f}m") 
    plt.legend(bbox_to_anchor=(1, 1))

plt.show()
print(f"max distance: {max_distance:.1f}m angle={best_angle:.1f}")
# Out:
# max distance: 91.5m angle=45.0

# %% [markdown]
# # Project. Train a neural network to predict a projectile range
#
# We can also train a machine learning model to predict projectile range. In machine learning finding a continuous value is a problem of regression. We will use Keras to build the model, and Scikit-learn to generate a dataset for training. Since we know the formula for the range of projectile (see Formula 2-1), generating a training dataset should be easy:

# %%
import numpy as np
from sklearn.model_selection import train_test_split

g = 9.81

def generate_data(size=1000):
    v = np.random.uniform(5, 35, size)
    alpha = np.random.uniform(20,60, size)
    projectile_range = [np.power(v,2)*np.sin(np.deg2rad(2*alpha)) / g]
    y = np.reshape(projectile_range, (size, 1))
    return train_test_split(np.vstack([v,alpha]).transpose(), y, test_size=0.2, random_state=42)

X_train, X_test, Y_train, Y_test = generate_data()

# %% [markdown]
# I set the dataset size to 1000 by default, release speed is in range 5-35 m/s, release angle 20-60 degrees. Resulting data is automatically split into training and test set, the input X is an array with rows containing release speed and release angle values, and the output contains predicted range:

# %%
print(f"Input set: {X_train.shape} sample value: {X_train[0]}")
print(f"Predicted set: {Y_train.shape} sample value: {Y_train[0]}")
# Out:
# Input set: (800, 2) sample value: [34.38954536 57.37380989]
# Predicted set: (800, 1) sample value: [109.48295258]

# %% [markdown]
# Next step is building a network in Keras to predict the projectile range. I used a simple network with two hidden layers, and the last layer is a linear layer with no activation. MSE loss function is used a lot in regression models. The MAE (mean absolute error) metric is the value difference between the predictions and the targets. For example a MAE of 0.99 means that you are off by 99 centimeters from the target range:

# %%
from keras import models
from keras import layers
from keras import callbacks

def build_model():
    model = models.Sequential()
    model.add(layers.Dense(64, activation='relu', input_dim=2))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(1))
    model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
    return model

# %% [markdown]
# Now the network is build, let's train it! The best model will be saved in projectile.hdf5 file.

# %%
model = build_model()
checkpoint = callbacks.ModelCheckpoint(filepath="projectile.hdf5", verbose=1, save_best_only=True)
model.fit(X_train, Y_train, epochs=500, batch_size=10, callbacks=[checkpoint])
score = model.evaluate(X_test, Y_test)
Y_pred = model.predict(X_test)
print('Score:', score)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\rl\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\rl\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\rl\lib\site-packages\keras\backend\tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/500
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\rl\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\rl\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\rl\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\rl\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\rl\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 800/800 [==============================] - 1s 983us/step - loss: 804.7435 - mean_absolute_error: 22.1535
# Epoch 2/500
# 800/800 [==============================] - 0s 140us/step - loss: 192.6858 - mean_absolute_error: 11.3954
# Epoch 3/500
# 300/800 [==========>...................] - ETA: 0s - loss: 140.5159 - mean_absolute_error: 9.2322
# C:\ProgramData\Anaconda3\envs\rl\lib\site-packages\keras\callbacks.py:434: RuntimeWarning: Can save best model only with val_loss available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# 800/800 [==============================] - 0s 201us/step - loss: 134.7567 - mean_absolute_error: 9.0314
# Epoch 4/500
# 800/800 [==============================] - 0s 179us/step - loss: 126.6879 - mean_absolute_error: 8.5874
# Epoch 5/500
# 800/800 [==============================] - 0s 158us/step - loss: 123.1336 - mean_absolute_error: 8.4167
# Epoch 6/500
# 800/800 [==============================] - 0s 141us/step - loss: 119.6960 - mean_absolute_error: 8.3334
# Epoch 7/500
# 800/800 [==============================] - 0s 201us/step - loss: 117.5343 - mean_absolute_error: 8.1332
# Epoch 8/500
# 800/800 [==============================] - 0s 176us/step - loss: 115.9178 - mean_absolute_error: 8.0482
# Epoch 9/500
# 800/800 [==============================] - 0s 196us/step - loss: 111.6828 - mean_absolute_error: 7.9424
# Epoch 10/500
# 800/800 [==============================] - 0s 193us/step - loss: 110.2635 - mean_absolute_error: 7.8287
# Epoch 11/500
# 800/800 [==============================] - 0s 180us/step - loss: 107.8630 - mean_absolute_error: 7.7017
# Epoch 12/500
# 800/800 [==============================] - 0s 193us/step - loss: 105.0331 - mean_absolute_error: 7.5787
# Epoch 13/500
# 800/800 [==============================] - 0s 170us/step - loss: 100.6758 - mean_absolute_error: 7.4445
# Epoch 14/500
# 800/800 [==============================] - 0s 136us/step - loss: 101.2935 - mean_absolute_error: 7.4032
# Epoch 15/500
# 800/800 [==============================] - 0s 134us/step - loss: 96.4327 - mean_absolute_error: 7.2347
# Epoch 16/500
# 800/800 [==============================] - 0s 126us/step - loss: 92.7302 - mean_absolute_error: 7.0784
# Epoch 17/500
# 800/800 [==============================] - 0s 137us/step - loss: 91.7082 - mean_absolute_error: 7.0171
# Epoch 18/500
# 800/800 [==============================] - 0s 165us/step - loss: 87.8213 - mean_absolute_error: 6.9114
# Epoch 19/500
# 800/800 [==============================] - 0s 213us/step - loss: 85.0764 - mean_absolute_error: 6.7480
# Epoch 20/500
# 800/800 [==============================] - 0s 140us/step - loss: 83.6802 - mean_absolute_error: 6.6597
# Epoch 21/500
# 800/800 [==============================] - 0s 151us/step - loss: 80.1888 - mean_absolute_error: 6.4915
# Epoch 22/500
# 800/800 [==============================] - 0s 141us/step - loss: 73.9800 - mean_absolute_error: 6.3037
# Epoch 23/500
# 800/800 [==============================] - 0s 121us/step - loss: 71.3941 - mean_absolute_error: 6.1180
# Epoch 24/500
# 800/800 [==============================] - 0s 109us/step - loss: 67.2668 - mean_absolute_error: 6.0498
# Epoch 25/500
# 800/800 [==============================] - 0s 129us/step - loss: 65.8218 - mean_absolute_error: 5.9517
# Epoch 26/500
# 800/800 [==============================] - 0s 155us/step - loss: 62.5867 - mean_absolute_error: 5.7706
# Epoch 27/500
# 800/800 [==============================] - 0s 180us/step - loss: 57.6712 - mean_absolute_error: 5.4310
# Epoch 28/500
# 800/800 [==============================] - 0s 126us/step - loss: 53.3798 - mean_absolute_error: 5.3307
# Epoch 29/500
# 800/800 [==============================] - 0s 318us/step - loss: 52.2709 - mean_absolute_error: 5.2854
# Epoch 30/500
# 800/800 [==============================] - 0s 269us/step - loss: 46.9418 - mean_absolute_error: 5.0513
# Epoch 31/500
# 800/800 [==============================] - 0s 211us/step - loss: 46.9303 - mean_absolute_error: 5.0249
# Epoch 32/500
# 800/800 [==============================] - 0s 169us/step - loss: 42.8355 - mean_absolute_error: 4.8449
# Epoch 33/500
# 800/800 [==============================] - 0s 167us/step - loss: 40.2462 - mean_absolute_error: 4.7347
# Epoch 34/500
# 800/800 [==============================] - 0s 213us/step - loss: 39.7911 - mean_absolute_error: 4.6713
# Epoch 35/500
# 800/800 [==============================] - 0s 197us/step - loss: 37.7595 - mean_absolute_error: 4.6157
# Epoch 36/500
# 800/800 [==============================] - 0s 148us/step - loss: 35.4790 - mean_absolute_error: 4.3512
# Epoch 37/500
# 800/800 [==============================] - 0s 175us/step - loss: 31.9798 - mean_absolute_error: 4.2391
# Epoch 38/500
# 800/800 [==============================] - 0s 166us/step - loss: 30.9521 - mean_absolute_error: 4.1690
# Epoch 39/500
# 800/800 [==============================] - 0s 194us/step - loss: 29.8423 - mean_absolute_error: 4.1568
# Epoch 40/500
# 800/800 [==============================] - 0s 154us/step - loss: 31.4793 - mean_absolute_error: 4.2112
# Epoch 41/500
# 800/800 [==============================] - 0s 160us/step - loss: 27.5092 - mean_absolute_error: 3.9532
# Epoch 42/500
# 800/800 [==============================] - 0s 153us/step - loss: 25.5132 - mean_absolute_error: 3.8240
# Epoch 43/500
# 800/800 [==============================] - 0s 161us/step - loss: 25.2958 - mean_absolute_error: 3.8244
# Epoch 44/500
# 800/800 [==============================] - 0s 183us/step - loss: 25.6723 - mean_absolute_error: 3.8778
# Epoch 45/500
# 800/800 [==============================] - 0s 208us/step - loss: 22.5450 - mean_absolute_error: 3.6178
# Epoch 46/500
# 800/800 [==============================] - 0s 127us/step - loss: 22.3313 - mean_absolute_error: 3.5698
# Epoch 47/500
# 800/800 [==============================] - 0s 99us/step - loss: 21.7360 - mean_absolute_error: 3.4934
# Epoch 48/500
# 800/800 [==============================] - 0s 111us/step - loss: 21.7074 - mean_absolute_error: 3.5235
# Epoch 49/500
# 800/800 [==============================] - 0s 101us/step - loss: 20.9578 - mean_absolute_error: 3.4729
# Epoch 50/500
# 800/800 [==============================] - 0s 99us/step - loss: 19.7320 - mean_absolute_error: 3.3546
# Epoch 51/500
# 800/800 [==============================] - 0s 110us/step - loss: 20.1711 - mean_absolute_error: 3.4284
# Epoch 52/500
# 800/800 [==============================] - 0s 117us/step - loss: 17.2740 - mean_absolute_error: 3.1887
# Epoch 53/500
# 800/800 [==============================] - 0s 100us/step - loss: 18.4269 - mean_absolute_error: 3.2989
# Epoch 54/500
# 800/800 [==============================] - 0s 94us/step - loss: 19.2878 - mean_absolute_error: 3.3630
# Epoch 55/500
# 800/800 [==============================] - 0s 100us/step - loss: 16.4147 - mean_absolute_error: 3.1078
# Epoch 56/500
# 800/800 [==============================] - 0s 115us/step - loss: 17.5120 - mean_absolute_error: 3.2424
# Epoch 57/500
# 800/800 [==============================] - 0s 103us/step - loss: 16.6916 - mean_absolute_error: 3.0899
# Epoch 58/500
# 800/800 [==============================] - 0s 111us/step - loss: 15.2534 - mean_absolute_error: 2.9910
# Epoch 59/500
# 800/800 [==============================] - 0s 149us/step - loss: 16.0033 - mean_absolute_error: 3.1142
# Epoch 60/500
# 800/800 [==============================] - 0s 114us/step - loss: 14.8346 - mean_absolute_error: 2.8889
# Epoch 61/500
# 800/800 [==============================] - 0s 114us/step - loss: 14.6696 - mean_absolute_error: 2.9486
# Epoch 62/500
# 800/800 [==============================] - 0s 107us/step - loss: 15.4549 - mean_absolute_error: 2.9977
# Epoch 63/500
# 800/800 [==============================] - 0s 109us/step - loss: 13.5398 - mean_absolute_error: 2.8780
# Epoch 64/500
# 800/800 [==============================] - 0s 114us/step - loss: 13.5299 - mean_absolute_error: 2.8238
# Epoch 65/500
# 800/800 [==============================] - 0s 105us/step - loss: 13.6488 - mean_absolute_error: 2.8173
# Epoch 66/500
# 800/800 [==============================] - 0s 100us/step - loss: 13.5230 - mean_absolute_error: 2.8415
# Epoch 67/500
# 800/800 [==============================] - 0s 99us/step - loss: 12.5208 - mean_absolute_error: 2.6705
# Epoch 68/500
# 800/800 [==============================] - 0s 108us/step - loss: 12.4304 - mean_absolute_error: 2.7672
# Epoch 69/500
# 800/800 [==============================] - 0s 106us/step - loss: 11.8596 - mean_absolute_error: 2.7063
# Epoch 70/500
# 800/800 [==============================] - 0s 108us/step - loss: 10.8127 - mean_absolute_error: 2.5674
# Epoch 71/500
# 800/800 [==============================] - 0s 95us/step - loss: 11.4282 - mean_absolute_error: 2.5311
# Epoch 72/500
# 800/800 [==============================] - 0s 99us/step - loss: 11.7786 - mean_absolute_error: 2.6533
# Epoch 73/500
# 800/800 [==============================] - 0s 103us/step - loss: 11.9569 - mean_absolute_error: 2.7176
# Epoch 74/500
# 800/800 [==============================] - 0s 109us/step - loss: 10.7951 - mean_absolute_error: 2.4748
# Epoch 75/500
# 800/800 [==============================] - 0s 120us/step - loss: 10.8678 - mean_absolute_error: 2.4749
# Epoch 76/500
# 800/800 [==============================] - 0s 115us/step - loss: 10.7451 - mean_absolute_error: 2.5243
# Epoch 77/500
# 800/800 [==============================] - 0s 118us/step - loss: 10.6521 - mean_absolute_error: 2.4871
# Epoch 78/500
# 800/800 [==============================] - 0s 97us/step - loss: 11.2042 - mean_absolute_error: 2.5408
# Epoch 79/500
# 800/800 [==============================] - 0s 99us/step - loss: 10.1429 - mean_absolute_error: 2.3793
# Epoch 80/500
# 800/800 [==============================] - 0s 126us/step - loss: 9.6986 - mean_absolute_error: 2.2882
# Epoch 81/500
# 800/800 [==============================] - 0s 95us/step - loss: 10.6271 - mean_absolute_error: 2.4430
# Epoch 82/500
# 800/800 [==============================] - 0s 104us/step - loss: 9.4942 - mean_absolute_error: 2.2946
# Epoch 83/500
# 800/800 [==============================] - 0s 123us/step - loss: 10.2359 - mean_absolute_error: 2.3533
# Epoch 84/500
# 800/800 [==============================] - 0s 106us/step - loss: 9.6957 - mean_absolute_error: 2.2875
# Epoch 85/500
# 800/800 [==============================] - 0s 95us/step - loss: 9.3981 - mean_absolute_error: 2.3662
# Epoch 86/500
# 800/800 [==============================] - 0s 118us/step - loss: 9.0624 - mean_absolute_error: 2.2748
# Epoch 87/500
# 800/800 [==============================] - 0s 111us/step - loss: 8.8070 - mean_absolute_error: 2.1704
# Epoch 88/500
# 800/800 [==============================] - 0s 103us/step - loss: 10.0883 - mean_absolute_error: 2.3950
# Epoch 89/500
# 800/800 [==============================] - 0s 100us/step - loss: 9.7799 - mean_absolute_error: 2.3249
# Epoch 90/500
# 800/800 [==============================] - 0s 97us/step - loss: 9.4167 - mean_absolute_error: 2.3604
# Epoch 91/500
# 800/800 [==============================] - 0s 100us/step - loss: 8.1396 - mean_absolute_error: 2.2014
# Epoch 92/500
# 800/800 [==============================] - 0s 103us/step - loss: 7.9491 - mean_absolute_error: 2.0493
# Epoch 93/500
# 800/800 [==============================] - 0s 101us/step - loss: 8.6746 - mean_absolute_error: 2.0760
# Epoch 94/500
# 800/800 [==============================] - 0s 116us/step - loss: 8.7582 - mean_absolute_error: 2.1797
# Epoch 95/500
# 800/800 [==============================] - 0s 109us/step - loss: 8.8041 - mean_absolute_error: 2.2517
# Epoch 96/500
# 800/800 [==============================] - 0s 135us/step - loss: 8.2313 - mean_absolute_error: 2.0373
# Epoch 97/500
# 800/800 [==============================] - 0s 164us/step - loss: 7.2975 - mean_absolute_error: 1.9568
# Epoch 98/500
# 800/800 [==============================] - 0s 125us/step - loss: 8.5762 - mean_absolute_error: 2.2207
# Epoch 99/500
# 800/800 [==============================] - 0s 124us/step - loss: 7.7378 - mean_absolute_error: 2.1260
# Epoch 100/500
# 800/800 [==============================] - 0s 124us/step - loss: 8.7527 - mean_absolute_error: 2.2479
# Epoch 101/500
# 800/800 [==============================] - 0s 161us/step - loss: 8.7557 - mean_absolute_error: 2.2146
# Epoch 102/500
# 800/800 [==============================] - 0s 166us/step - loss: 8.0108 - mean_absolute_error: 2.1504
# Epoch 103/500
# 800/800 [==============================] - 0s 120us/step - loss: 7.1417 - mean_absolute_error: 2.0639
# Epoch 104/500
# 800/800 [==============================] - 0s 135us/step - loss: 8.2527 - mean_absolute_error: 2.1550
# Epoch 105/500
# 800/800 [==============================] - 0s 128us/step - loss: 8.3613 - mean_absolute_error: 2.1778
# Epoch 106/500
# 800/800 [==============================] - 0s 114us/step - loss: 8.1828 - mean_absolute_error: 2.1360
# Epoch 107/500
# 800/800 [==============================] - 0s 114us/step - loss: 8.1031 - mean_absolute_error: 2.0751
# Epoch 108/500
# 800/800 [==============================] - 0s 109us/step - loss: 7.3887 - mean_absolute_error: 2.0645
# Epoch 109/500
# 800/800 [==============================] - 0s 103us/step - loss: 8.8453 - mean_absolute_error: 2.2092
# Epoch 110/500
# 800/800 [==============================] - 0s 88us/step - loss: 7.3699 - mean_absolute_error: 1.9471
# Epoch 111/500
# 800/800 [==============================] - 0s 121us/step - loss: 8.3413 - mean_absolute_error: 2.0810
# Epoch 112/500
# 800/800 [==============================] - 0s 116us/step - loss: 8.2426 - mean_absolute_error: 2.0167
# Epoch 113/500
# 800/800 [==============================] - 0s 99us/step - loss: 7.2479 - mean_absolute_error: 2.0082
# Epoch 114/500
# 800/800 [==============================] - 0s 126us/step - loss: 8.3434 - mean_absolute_error: 2.1640
# Epoch 115/500
# 800/800 [==============================] - 0s 91us/step - loss: 8.1566 - mean_absolute_error: 2.1295
# Epoch 116/500
# 800/800 [==============================] - 0s 90us/step - loss: 8.3059 - mean_absolute_error: 2.0922
# Epoch 117/500
# 800/800 [==============================] - 0s 100us/step - loss: 6.3692 - mean_absolute_error: 1.8990
# Epoch 118/500
# 800/800 [==============================] - 0s 125us/step - loss: 7.9046 - mean_absolute_error: 2.1129
# Epoch 119/500
# 800/800 [==============================] - 0s 109us/step - loss: 7.4670 - mean_absolute_error: 2.0329
# Epoch 120/500
# 800/800 [==============================] - 0s 105us/step - loss: 6.8572 - mean_absolute_error: 1.9342
# Epoch 121/500
# 800/800 [==============================] - 0s 92us/step - loss: 7.9307 - mean_absolute_error: 2.0167
# Epoch 122/500
# 800/800 [==============================] - 0s 89us/step - loss: 7.2513 - mean_absolute_error: 2.0463
# Epoch 123/500
# 800/800 [==============================] - 0s 87us/step - loss: 7.3077 - mean_absolute_error: 2.0615
# Epoch 124/500
# 800/800 [==============================] - 0s 106us/step - loss: 5.8528 - mean_absolute_error: 1.7755
# Epoch 125/500
# 800/800 [==============================] - 0s 112us/step - loss: 8.0247 - mean_absolute_error: 2.1079
# Epoch 126/500
# 800/800 [==============================] - 0s 159us/step - loss: 7.1751 - mean_absolute_error: 1.9324
# Epoch 127/500
# 800/800 [==============================] - 0s 114us/step - loss: 7.4795 - mean_absolute_error: 1.9893
# Epoch 128/500
# 800/800 [==============================] - 0s 105us/step - loss: 7.2658 - mean_absolute_error: 1.9356
# Epoch 129/500
# 800/800 [==============================] - 0s 106us/step - loss: 7.5301 - mean_absolute_error: 1.9606
# Epoch 130/500
# 800/800 [==============================] - 0s 181us/step - loss: 6.5070 - mean_absolute_error: 1.8827
# Epoch 131/500
# 800/800 [==============================] - 0s 124us/step - loss: 6.8248 - mean_absolute_error: 1.9052
# Epoch 132/500
# 800/800 [==============================] - 0s 103us/step - loss: 7.4539 - mean_absolute_error: 2.0452
# Epoch 133/500
# 800/800 [==============================] - 0s 95us/step - loss: 6.4566 - mean_absolute_error: 1.8563
# Epoch 134/500
# 800/800 [==============================] - 0s 150us/step - loss: 6.9188 - mean_absolute_error: 1.9618
# Epoch 135/500
# 800/800 [==============================] - 0s 121us/step - loss: 6.8034 - mean_absolute_error: 1.8727
# Epoch 136/500
# 800/800 [==============================] - 0s 89us/step - loss: 6.3904 - mean_absolute_error: 1.8126
# Epoch 137/500
# 800/800 [==============================] - 0s 88us/step - loss: 7.3927 - mean_absolute_error: 1.9053
# Epoch 138/500
# 800/800 [==============================] - 0s 100us/step - loss: 7.1486 - mean_absolute_error: 1.9875
# Epoch 139/500
# 800/800 [==============================] - 0s 94us/step - loss: 7.0127 - mean_absolute_error: 1.9118
# Epoch 140/500
# 800/800 [==============================] - 0s 116us/step - loss: 6.5624 - mean_absolute_error: 1.8290
# Epoch 141/500
# 800/800 [==============================] - 0s 96us/step - loss: 6.8980 - mean_absolute_error: 1.8273
# Epoch 142/500
# 800/800 [==============================] - 0s 143us/step - loss: 5.6511 - mean_absolute_error: 1.7196
# Epoch 143/500
# 800/800 [==============================] - 0s 118us/step - loss: 6.4073 - mean_absolute_error: 1.8722
# Epoch 144/500
# 800/800 [==============================] - 0s 107us/step - loss: 6.4135 - mean_absolute_error: 1.8172
# Epoch 145/500
# 800/800 [==============================] - 0s 101us/step - loss: 6.9689 - mean_absolute_error: 1.8960
# Epoch 146/500
# 800/800 [==============================] - 0s 101us/step - loss: 6.9286 - mean_absolute_error: 1.8659
# Epoch 147/500
# 800/800 [==============================] - 0s 101us/step - loss: 5.5581 - mean_absolute_error: 1.7321
# Epoch 148/500
# 800/800 [==============================] - 0s 90us/step - loss: 6.1936 - mean_absolute_error: 1.8041
# Epoch 149/500
# 800/800 [==============================] - 0s 88us/step - loss: 5.8577 - mean_absolute_error: 1.7739
# Epoch 150/500
# 800/800 [==============================] - 0s 114us/step - loss: 6.3945 - mean_absolute_error: 1.8634
# Epoch 151/500
# 800/800 [==============================] - 0s 91us/step - loss: 6.1202 - mean_absolute_error: 1.8454
# Epoch 152/500
# 800/800 [==============================] - 0s 118us/step - loss: 6.2665 - mean_absolute_error: 1.7494
# Epoch 153/500
# 800/800 [==============================] - 0s 143us/step - loss: 7.1287 - mean_absolute_error: 1.8835
# Epoch 154/500
# 800/800 [==============================] - 0s 115us/step - loss: 6.0220 - mean_absolute_error: 1.8172
# Epoch 155/500
# 800/800 [==============================] - 0s 104us/step - loss: 5.9583 - mean_absolute_error: 1.6799
# Epoch 156/500
# 800/800 [==============================] - 0s 96us/step - loss: 5.7627 - mean_absolute_error: 1.6932
# Epoch 157/500
# 800/800 [==============================] - 0s 95us/step - loss: 6.3347 - mean_absolute_error: 1.8477
# Epoch 158/500
# 800/800 [==============================] - 0s 90us/step - loss: 6.5864 - mean_absolute_error: 1.8328
# Epoch 159/500
# 800/800 [==============================] - 0s 118us/step - loss: 5.2968 - mean_absolute_error: 1.6617
# Epoch 160/500
# 800/800 [==============================] - 0s 106us/step - loss: 6.0928 - mean_absolute_error: 1.7495
# Epoch 161/500
# 800/800 [==============================] - 0s 116us/step - loss: 5.3847 - mean_absolute_error: 1.6331
# Epoch 162/500
# 800/800 [==============================] - 0s 123us/step - loss: 5.6342 - mean_absolute_error: 1.7077
# Epoch 163/500
# 800/800 [==============================] - 0s 116us/step - loss: 5.4564 - mean_absolute_error: 1.7827
# Epoch 164/500
# 800/800 [==============================] - 0s 128us/step - loss: 5.7389 - mean_absolute_error: 1.6425
# Epoch 165/500
# 800/800 [==============================] - 0s 113us/step - loss: 6.1644 - mean_absolute_error: 1.7540
# Epoch 166/500
# 800/800 [==============================] - 0s 101us/step - loss: 5.6845 - mean_absolute_error: 1.7523
# Epoch 167/500
# 800/800 [==============================] - 0s 104us/step - loss: 4.9935 - mean_absolute_error: 1.5649
# Epoch 168/500
# 800/800 [==============================] - 0s 115us/step - loss: 6.6218 - mean_absolute_error: 1.8803
# Epoch 169/500
# 800/800 [==============================] - 0s 99us/step - loss: 5.4784 - mean_absolute_error: 1.6453
# Epoch 170/500
# 800/800 [==============================] - ETA: 0s - loss: 5.4781 - mean_absolute_error: 1.563 - 0s 111us/step - loss: 5.6601 - mean_absolute_error: 1.6287
# Epoch 171/500
# 800/800 [==============================] - 0s 100us/step - loss: 6.2912 - mean_absolute_error: 1.7216
# Epoch 172/500
# 800/800 [==============================] - 0s 127us/step - loss: 5.4310 - mean_absolute_error: 1.6743
# Epoch 173/500
# 800/800 [==============================] - 0s 116us/step - loss: 6.0218 - mean_absolute_error: 1.7767
# Epoch 174/500
# 800/800 [==============================] - 0s 118us/step - loss: 4.8475 - mean_absolute_error: 1.6400
# Epoch 175/500
# 800/800 [==============================] - 0s 135us/step - loss: 5.4984 - mean_absolute_error: 1.6234
# Epoch 176/500
# 800/800 [==============================] - 0s 105us/step - loss: 5.7394 - mean_absolute_error: 1.7295
# Epoch 177/500
# 800/800 [==============================] - 0s 108us/step - loss: 5.2727 - mean_absolute_error: 1.6472
# Epoch 178/500
# 800/800 [==============================] - 0s 121us/step - loss: 5.3990 - mean_absolute_error: 1.6354
# Epoch 179/500
# 800/800 [==============================] - 0s 143us/step - loss: 6.0310 - mean_absolute_error: 1.7747
# Epoch 180/500
# 800/800 [==============================] - 0s 110us/step - loss: 5.4938 - mean_absolute_error: 1.6403
# Epoch 181/500
# 800/800 [==============================] - 0s 109us/step - loss: 5.5615 - mean_absolute_error: 1.5496
# Epoch 182/500
# 800/800 [==============================] - 0s 114us/step - loss: 5.2122 - mean_absolute_error: 1.6713
# Epoch 183/500
# 800/800 [==============================] - 0s 117us/step - loss: 5.1753 - mean_absolute_error: 1.6097
# Epoch 184/500
# 800/800 [==============================] - 0s 115us/step - loss: 5.6791 - mean_absolute_error: 1.6649
# Epoch 185/500
# 800/800 [==============================] - 0s 109us/step - loss: 5.0078 - mean_absolute_error: 1.5808
# Epoch 186/500
# 800/800 [==============================] - 0s 95us/step - loss: 5.9687 - mean_absolute_error: 1.6696
# Epoch 187/500
# 800/800 [==============================] - 0s 103us/step - loss: 5.1509 - mean_absolute_error: 1.5872
# Epoch 188/500
# 800/800 [==============================] - 0s 100us/step - loss: 5.3544 - mean_absolute_error: 1.6279
# Epoch 189/500
# 800/800 [==============================] - 0s 85us/step - loss: 5.3134 - mean_absolute_error: 1.6290
# Epoch 190/500
# 800/800 [==============================] - 0s 90us/step - loss: 5.4280 - mean_absolute_error: 1.5680
# Epoch 191/500
# 800/800 [==============================] - 0s 135us/step - loss: 5.7509 - mean_absolute_error: 1.6188
# Epoch 192/500
# 800/800 [==============================] - 0s 144us/step - loss: 4.2472 - mean_absolute_error: 1.4136
# Epoch 193/500
# 800/800 [==============================] - 0s 130us/step - loss: 5.5687 - mean_absolute_error: 1.6025
# Epoch 194/500
# 800/800 [==============================] - 0s 183us/step - loss: 4.8649 - mean_absolute_error: 1.5395
# Epoch 195/500
# 800/800 [==============================] - 0s 264us/step - loss: 5.0509 - mean_absolute_error: 1.6375
# Epoch 196/500
# 800/800 [==============================] - 0s 197us/step - loss: 5.1181 - mean_absolute_error: 1.5964
# Epoch 197/500
# 800/800 [==============================] - 0s 123us/step - loss: 4.8732 - mean_absolute_error: 1.5479
# Epoch 198/500
# 800/800 [==============================] - 0s 136us/step - loss: 5.1019 - mean_absolute_error: 1.5624
# Epoch 199/500
# 800/800 [==============================] - 0s 128us/step - loss: 4.9059 - mean_absolute_error: 1.6139
# Epoch 200/500
# 800/800 [==============================] - 0s 147us/step - loss: 4.9287 - mean_absolute_error: 1.5197
# Epoch 201/500
# 800/800 [==============================] - 0s 117us/step - loss: 5.2288 - mean_absolute_error: 1.6602
# Epoch 202/500
# 800/800 [==============================] - 0s 139us/step - loss: 5.0252 - mean_absolute_error: 1.6076
# Epoch 203/500
# 800/800 [==============================] - 0s 160us/step - loss: 4.9611 - mean_absolute_error: 1.5775
# Epoch 204/500
# 800/800 [==============================] - 0s 125us/step - loss: 4.4707 - mean_absolute_error: 1.4602
# Epoch 205/500
# 800/800 [==============================] - 0s 162us/step - loss: 5.0728 - mean_absolute_error: 1.5932
# Epoch 206/500
# 800/800 [==============================] - 0s 145us/step - loss: 4.8426 - mean_absolute_error: 1.5206
# Epoch 207/500
# 800/800 [==============================] - 0s 161us/step - loss: 4.6103 - mean_absolute_error: 1.5108
# Epoch 208/500
# 800/800 [==============================] - 0s 126us/step - loss: 4.7180 - mean_absolute_error: 1.5339
# Epoch 209/500
# 800/800 [==============================] - 0s 118us/step - loss: 4.9755 - mean_absolute_error: 1.6208
# Epoch 210/500
# 800/800 [==============================] - 0s 140us/step - loss: 4.9047 - mean_absolute_error: 1.5355
# Epoch 211/500
# 800/800 [==============================] - 0s 148us/step - loss: 4.8680 - mean_absolute_error: 1.5914
# Epoch 212/500
# 800/800 [==============================] - 0s 137us/step - loss: 4.6146 - mean_absolute_error: 1.5137
# Epoch 213/500
# 800/800 [==============================] - 0s 99us/step - loss: 4.6105 - mean_absolute_error: 1.3912
# Epoch 214/500
# 800/800 [==============================] - 0s 81us/step - loss: 4.9260 - mean_absolute_error: 1.5884
# Epoch 215/500
# 800/800 [==============================] - 0s 104us/step - loss: 4.8561 - mean_absolute_error: 1.5210
# Epoch 216/500
# 800/800 [==============================] - 0s 111us/step - loss: 4.5721 - mean_absolute_error: 1.4864
# Epoch 217/500
# 800/800 [==============================] - 0s 104us/step - loss: 4.6746 - mean_absolute_error: 1.4971
# Epoch 218/500
# 800/800 [==============================] - 0s 107us/step - loss: 4.0006 - mean_absolute_error: 1.4227
# Epoch 219/500
# 800/800 [==============================] - 0s 95us/step - loss: 4.7498 - mean_absolute_error: 1.5336
# Epoch 220/500
# 800/800 [==============================] - 0s 100us/step - loss: 4.3220 - mean_absolute_error: 1.4648
# Epoch 221/500
# 800/800 [==============================] - 0s 123us/step - loss: 4.6124 - mean_absolute_error: 1.4878
# Epoch 222/500
# 800/800 [==============================] - 0s 114us/step - loss: 4.6891 - mean_absolute_error: 1.4105
# Epoch 223/500
# 800/800 [==============================] - 0s 100us/step - loss: 4.9390 - mean_absolute_error: 1.5170
# Epoch 224/500
# 800/800 [==============================] - 0s 104us/step - loss: 4.8628 - mean_absolute_error: 1.5096
# Epoch 225/500
# 800/800 [==============================] - 0s 111us/step - loss: 4.4701 - mean_absolute_error: 1.5314
# Epoch 226/500
# 800/800 [==============================] - 0s 114us/step - loss: 4.2329 - mean_absolute_error: 1.4438
# Epoch 227/500
# 800/800 [==============================] - 0s 114us/step - loss: 3.9560 - mean_absolute_error: 1.4318
# Epoch 228/500
# 800/800 [==============================] - 0s 101us/step - loss: 4.3235 - mean_absolute_error: 1.3982
# Epoch 229/500
# 800/800 [==============================] - 0s 134us/step - loss: 4.2678 - mean_absolute_error: 1.4613
# Epoch 230/500
# 800/800 [==============================] - 0s 124us/step - loss: 4.2456 - mean_absolute_error: 1.4955
# Epoch 231/500
# 800/800 [==============================] - 0s 160us/step - loss: 4.2654 - mean_absolute_error: 1.3329
# Epoch 232/500
# 800/800 [==============================] - 0s 114us/step - loss: 4.5685 - mean_absolute_error: 1.4644
# Epoch 233/500
# 800/800 [==============================] - 0s 141us/step - loss: 4.5230 - mean_absolute_error: 1.4803
# Epoch 234/500
# 800/800 [==============================] - 0s 138us/step - loss: 3.8368 - mean_absolute_error: 1.3386
# Epoch 235/500
# 800/800 [==============================] - 0s 230us/step - loss: 4.5912 - mean_absolute_error: 1.4025
# Epoch 236/500
# 800/800 [==============================] - 0s 203us/step - loss: 3.9641 - mean_absolute_error: 1.3888
# Epoch 237/500
# 800/800 [==============================] - 0s 178us/step - loss: 4.3455 - mean_absolute_error: 1.3945
# Epoch 238/500
# 800/800 [==============================] - 0s 134us/step - loss: 4.1684 - mean_absolute_error: 1.3753
# Epoch 239/500
# 800/800 [==============================] - 0s 150us/step - loss: 4.2444 - mean_absolute_error: 1.3746
# Epoch 240/500
# 800/800 [==============================] - 0s 112us/step - loss: 4.4985 - mean_absolute_error: 1.4122
# Epoch 241/500
# 800/800 [==============================] - 0s 116us/step - loss: 3.8826 - mean_absolute_error: 1.3427
# Epoch 242/500
# 800/800 [==============================] - 0s 135us/step - loss: 3.5583 - mean_absolute_error: 1.3324
# Epoch 243/500
# 800/800 [==============================] - 0s 130us/step - loss: 4.2315 - mean_absolute_error: 1.4067
# Epoch 244/500
# 800/800 [==============================] - 0s 134us/step - loss: 4.0036 - mean_absolute_error: 1.4619
# Epoch 245/500
# 800/800 [==============================] - 0s 120us/step - loss: 3.8174 - mean_absolute_error: 1.3622
# Epoch 246/500
# 800/800 [==============================] - 0s 133us/step - loss: 3.9529 - mean_absolute_error: 1.4500
# Epoch 247/500
# 800/800 [==============================] - 0s 142us/step - loss: 4.2128 - mean_absolute_error: 1.3483
# Epoch 248/500
# 800/800 [==============================] - 0s 162us/step - loss: 4.2045 - mean_absolute_error: 1.3792
# Epoch 249/500
# 800/800 [==============================] - 0s 152us/step - loss: 4.0390 - mean_absolute_error: 1.3511
# Epoch 250/500
# 800/800 [==============================] - 0s 140us/step - loss: 4.0231 - mean_absolute_error: 1.2986
# Epoch 251/500
# 800/800 [==============================] - 0s 121us/step - loss: 4.3477 - mean_absolute_error: 1.4183
# Epoch 252/500
# 800/800 [==============================] - 0s 151us/step - loss: 3.7993 - mean_absolute_error: 1.2905
# Epoch 253/500
# 800/800 [==============================] - 0s 116us/step - loss: 4.2795 - mean_absolute_error: 1.4633
# Epoch 254/500
# 800/800 [==============================] - 0s 118us/step - loss: 4.0210 - mean_absolute_error: 1.3869
# Epoch 255/500
# 800/800 [==============================] - 0s 141us/step - loss: 3.5867 - mean_absolute_error: 1.3085
# Epoch 256/500
# 800/800 [==============================] - 0s 123us/step - loss: 4.2721 - mean_absolute_error: 1.4054
# Epoch 257/500
# 800/800 [==============================] - 0s 94us/step - loss: 3.7038 - mean_absolute_error: 1.2899
# Epoch 258/500
# 800/800 [==============================] - 0s 176us/step - loss: 4.0061 - mean_absolute_error: 1.3661
# Epoch 259/500
# 800/800 [==============================] - 0s 145us/step - loss: 4.5551 - mean_absolute_error: 1.4542
# Epoch 260/500
# 800/800 [==============================] - 0s 145us/step - loss: 3.5138 - mean_absolute_error: 1.2486
# Epoch 261/500
# 800/800 [==============================] - 0s 154us/step - loss: 4.0821 - mean_absolute_error: 1.2956
# Epoch 262/500
# 800/800 [==============================] - 0s 219us/step - loss: 3.6832 - mean_absolute_error: 1.2362
# Epoch 263/500
# 800/800 [==============================] - 0s 185us/step - loss: 3.7994 - mean_absolute_error: 1.3418
# Epoch 264/500
# 800/800 [==============================] - 0s 158us/step - loss: 3.7394 - mean_absolute_error: 1.3002
# Epoch 265/500
# 800/800 [==============================] - 0s 206us/step - loss: 4.0675 - mean_absolute_error: 1.4182
# Epoch 266/500
# 800/800 [==============================] - 0s 168us/step - loss: 3.9750 - mean_absolute_error: 1.3455
# Epoch 267/500
# 800/800 [==============================] - 0s 151us/step - loss: 4.5954 - mean_absolute_error: 1.3902
# Epoch 268/500
# 800/800 [==============================] - 0s 128us/step - loss: 2.9781 - mean_absolute_error: 1.2161
# Epoch 269/500
# 800/800 [==============================] - 0s 110us/step - loss: 3.8432 - mean_absolute_error: 1.3428
# Epoch 270/500
# 800/800 [==============================] - 0s 105us/step - loss: 3.7875 - mean_absolute_error: 1.3392
# Epoch 271/500
# 800/800 [==============================] - 0s 94us/step - loss: 4.0698 - mean_absolute_error: 1.3234
# Epoch 272/500
# 800/800 [==============================] - 0s 96us/step - loss: 4.0722 - mean_absolute_error: 1.2884
# Epoch 273/500
# 800/800 [==============================] - 0s 114us/step - loss: 3.8139 - mean_absolute_error: 1.2637
# Epoch 274/500
# 800/800 [==============================] - 0s 125us/step - loss: 3.3953 - mean_absolute_error: 1.2383
# Epoch 275/500
# 800/800 [==============================] - 0s 90us/step - loss: 4.1469 - mean_absolute_error: 1.4013
# Epoch 276/500
# 800/800 [==============================] - 0s 95us/step - loss: 3.2558 - mean_absolute_error: 1.2605
# Epoch 277/500
# 800/800 [==============================] - 0s 95us/step - loss: 4.1506 - mean_absolute_error: 1.3537
# Epoch 278/500
# 800/800 [==============================] - 0s 91us/step - loss: 3.6244 - mean_absolute_error: 1.3237
# Epoch 279/500
# 800/800 [==============================] - 0s 102us/step - loss: 3.3289 - mean_absolute_error: 1.2544
# Epoch 280/500
# 800/800 [==============================] - 0s 134us/step - loss: 4.0984 - mean_absolute_error: 1.3432
# Epoch 281/500
# 800/800 [==============================] - 0s 123us/step - loss: 3.6264 - mean_absolute_error: 1.1669
# Epoch 282/500
# 800/800 [==============================] - 0s 143us/step - loss: 3.8991 - mean_absolute_error: 1.3011
# Epoch 283/500
# 800/800 [==============================] - 0s 127us/step - loss: 3.8441 - mean_absolute_error: 1.3674
# Epoch 284/500
# 800/800 [==============================] - 0s 126us/step - loss: 3.6501 - mean_absolute_error: 1.3050
# Epoch 285/500
# 800/800 [==============================] - 0s 176us/step - loss: 3.8536 - mean_absolute_error: 1.3065
# Epoch 286/500
# 800/800 [==============================] - 0s 123us/step - loss: 3.9128 - mean_absolute_error: 1.3396
# Epoch 287/500
# 800/800 [==============================] - 0s 162us/step - loss: 4.0073 - mean_absolute_error: 1.2991
# Epoch 288/500
# 800/800 [==============================] - 0s 150us/step - loss: 3.4197 - mean_absolute_error: 1.2872
# Epoch 289/500
# 800/800 [==============================] - 0s 151us/step - loss: 3.5680 - mean_absolute_error: 1.2611
# Epoch 290/500
# 800/800 [==============================] - 0s 136us/step - loss: 3.5178 - mean_absolute_error: 1.3074
# Epoch 291/500
# 800/800 [==============================] - 0s 120us/step - loss: 3.5484 - mean_absolute_error: 1.3560
# Epoch 292/500
# 800/800 [==============================] - 0s 134us/step - loss: 3.3626 - mean_absolute_error: 1.2233
# Epoch 293/500
# 800/800 [==============================] - 0s 123us/step - loss: 3.8336 - mean_absolute_error: 1.3460
# Epoch 294/500
# 800/800 [==============================] - 0s 121us/step - loss: 3.3879 - mean_absolute_error: 1.1854
# Epoch 295/500
# 800/800 [==============================] - 0s 145us/step - loss: 3.4927 - mean_absolute_error: 1.2772
# Epoch 296/500
# 800/800 [==============================] - 0s 111us/step - loss: 3.1458 - mean_absolute_error: 1.1980
# Epoch 297/500
# 800/800 [==============================] - 0s 82us/step - loss: 3.9952 - mean_absolute_error: 1.3388
# Epoch 298/500
# 800/800 [==============================] - 0s 114us/step - loss: 3.2636 - mean_absolute_error: 1.2280
# Epoch 299/500
# 800/800 [==============================] - 0s 91us/step - loss: 3.9084 - mean_absolute_error: 1.3377
# Epoch 300/500
# 800/800 [==============================] - 0s 98us/step - loss: 3.3366 - mean_absolute_error: 1.2785
# Epoch 301/500
# 800/800 [==============================] - 0s 94us/step - loss: 3.7002 - mean_absolute_error: 1.2801
# Epoch 302/500
# 800/800 [==============================] - 0s 104us/step - loss: 3.6998 - mean_absolute_error: 1.2617
# Epoch 303/500
# 800/800 [==============================] - 0s 116us/step - loss: 3.5036 - mean_absolute_error: 1.2730
# Epoch 304/500
# 800/800 [==============================] - 0s 101us/step - loss: 3.7497 - mean_absolute_error: 1.2030
# Epoch 305/500
# 800/800 [==============================] - 0s 96us/step - loss: 2.8645 - mean_absolute_error: 1.1153
# Epoch 306/500
# 800/800 [==============================] - 0s 99us/step - loss: 3.5892 - mean_absolute_error: 1.2495
# Epoch 307/500
# 800/800 [==============================] - 0s 110us/step - loss: 3.7840 - mean_absolute_error: 1.2881
# Epoch 308/500
# 800/800 [==============================] - 0s 104us/step - loss: 3.4478 - mean_absolute_error: 1.1980
# Epoch 309/500
# 800/800 [==============================] - 0s 105us/step - loss: 3.4278 - mean_absolute_error: 1.3266
# Epoch 310/500
# 800/800 [==============================] - 0s 105us/step - loss: 3.8925 - mean_absolute_error: 1.2898
# Epoch 311/500
# 800/800 [==============================] - 0s 97us/step - loss: 3.1984 - mean_absolute_error: 1.1429
# Epoch 312/500
# 800/800 [==============================] - 0s 98us/step - loss: 3.3624 - mean_absolute_error: 1.2769
# Epoch 313/500
# 800/800 [==============================] - 0s 99us/step - loss: 3.3794 - mean_absolute_error: 1.2498
# Epoch 314/500
# 800/800 [==============================] - 0s 108us/step - loss: 3.6142 - mean_absolute_error: 1.2313
# Epoch 315/500
# 800/800 [==============================] - 0s 109us/step - loss: 3.6787 - mean_absolute_error: 1.2545
# Epoch 316/500
# 800/800 [==============================] - 0s 91us/step - loss: 3.4480 - mean_absolute_error: 1.2927
# Epoch 317/500
# 800/800 [==============================] - 0s 100us/step - loss: 3.0810 - mean_absolute_error: 1.1566
# Epoch 318/500
# 800/800 [==============================] - 0s 98us/step - loss: 3.6714 - mean_absolute_error: 1.2859
# Epoch 319/500
# 800/800 [==============================] - 0s 109us/step - loss: 3.4856 - mean_absolute_error: 1.2642
# Epoch 320/500
# 800/800 [==============================] - 0s 105us/step - loss: 3.2126 - mean_absolute_error: 1.2286
# Epoch 321/500
# 800/800 [==============================] - 0s 109us/step - loss: 3.5876 - mean_absolute_error: 1.2476
# Epoch 322/500
# 800/800 [==============================] - 0s 101us/step - loss: 3.2104 - mean_absolute_error: 1.1703
# Epoch 323/500
# 800/800 [==============================] - 0s 109us/step - loss: 3.4996 - mean_absolute_error: 1.2320
# Epoch 324/500
# 800/800 [==============================] - 0s 105us/step - loss: 4.1623 - mean_absolute_error: 1.3605
# Epoch 325/500
# 800/800 [==============================] - 0s 110us/step - loss: 3.0920 - mean_absolute_error: 1.1441
# Epoch 326/500
# 800/800 [==============================] - 0s 110us/step - loss: 3.3218 - mean_absolute_error: 1.1828
# Epoch 327/500
# 800/800 [==============================] - 0s 101us/step - loss: 3.7186 - mean_absolute_error: 1.1631
# Epoch 328/500
# 800/800 [==============================] - 0s 106us/step - loss: 3.2838 - mean_absolute_error: 1.2340
# Epoch 329/500
# 800/800 [==============================] - 0s 96us/step - loss: 3.4671 - mean_absolute_error: 1.2162
# Epoch 330/500
# 800/800 [==============================] - 0s 101us/step - loss: 3.2756 - mean_absolute_error: 1.2370
# Epoch 331/500
# 800/800 [==============================] - 0s 108us/step - loss: 3.2793 - mean_absolute_error: 1.1765
# Epoch 332/500
# 800/800 [==============================] - 0s 99us/step - loss: 3.1118 - mean_absolute_error: 1.1750
# Epoch 333/500
# 800/800 [==============================] - 0s 96us/step - loss: 3.2968 - mean_absolute_error: 1.2607
# Epoch 334/500
# 800/800 [==============================] - 0s 103us/step - loss: 3.0824 - mean_absolute_error: 1.1915
# Epoch 335/500
# 800/800 [==============================] - 0s 111us/step - loss: 3.0760 - mean_absolute_error: 1.1807
# Epoch 336/500
# 800/800 [==============================] - 0s 112us/step - loss: 3.4509 - mean_absolute_error: 1.1951
# Epoch 337/500
# 800/800 [==============================] - 0s 106us/step - loss: 3.0814 - mean_absolute_error: 1.2081
# Epoch 338/500
# 800/800 [==============================] - 0s 115us/step - loss: 3.2511 - mean_absolute_error: 1.2182
# Epoch 339/500
# 800/800 [==============================] - 0s 100us/step - loss: 2.8735 - mean_absolute_error: 1.0618
# Epoch 340/500
# 800/800 [==============================] - 0s 94us/step - loss: 3.8389 - mean_absolute_error: 1.1501
# Epoch 341/500
# 800/800 [==============================] - 0s 95us/step - loss: 3.2542 - mean_absolute_error: 1.1498
# Epoch 342/500
# 800/800 [==============================] - 0s 103us/step - loss: 3.5236 - mean_absolute_error: 1.2249
# Epoch 343/500
# 800/800 [==============================] - 0s 100us/step - loss: 3.4838 - mean_absolute_error: 1.2428
# Epoch 344/500
# 800/800 [==============================] - 0s 94us/step - loss: 3.1987 - mean_absolute_error: 1.1893
# Epoch 345/500
# 800/800 [==============================] - 0s 109us/step - loss: 3.3493 - mean_absolute_error: 1.2183
# Epoch 346/500
# 800/800 [==============================] - 0s 106us/step - loss: 3.0880 - mean_absolute_error: 1.1737
# Epoch 347/500
# 800/800 [==============================] - 0s 94us/step - loss: 2.9391 - mean_absolute_error: 1.0791
# Epoch 348/500
# 800/800 [==============================] - 0s 94us/step - loss: 3.4279 - mean_absolute_error: 1.1632
# Epoch 349/500
# 800/800 [==============================] - 0s 105us/step - loss: 3.4867 - mean_absolute_error: 1.1473
# Epoch 350/500
# 800/800 [==============================] - 0s 93us/step - loss: 2.8429 - mean_absolute_error: 1.1678
# Epoch 351/500
# 800/800 [==============================] - 0s 92us/step - loss: 2.9749 - mean_absolute_error: 1.1369
# Epoch 352/500
# 800/800 [==============================] - 0s 88us/step - loss: 2.7736 - mean_absolute_error: 1.1645
# Epoch 353/500
# 800/800 [==============================] - 0s 96us/step - loss: 3.3899 - mean_absolute_error: 1.1853
# Epoch 354/500
# 800/800 [==============================] - 0s 86us/step - loss: 2.7327 - mean_absolute_error: 1.1155
# Epoch 355/500
# 800/800 [==============================] - 0s 85us/step - loss: 3.2376 - mean_absolute_error: 1.1485
# Epoch 356/500
# 800/800 [==============================] - 0s 95us/step - loss: 2.7773 - mean_absolute_error: 1.1532
# Epoch 357/500
# 800/800 [==============================] - 0s 99us/step - loss: 2.9650 - mean_absolute_error: 1.1491
# Epoch 358/500
# 800/800 [==============================] - 0s 97us/step - loss: 2.8252 - mean_absolute_error: 1.0786
# Epoch 359/500
# 800/800 [==============================] - 0s 97us/step - loss: 3.3462 - mean_absolute_error: 1.2886
# Epoch 360/500
# 800/800 [==============================] - 0s 102us/step - loss: 2.8437 - mean_absolute_error: 1.1642
# Epoch 361/500
# 800/800 [==============================] - 0s 92us/step - loss: 2.9483 - mean_absolute_error: 1.1675
# Epoch 362/500
# 800/800 [==============================] - 0s 91us/step - loss: 2.9262 - mean_absolute_error: 1.0373
# Epoch 363/500
# 800/800 [==============================] - 0s 99us/step - loss: 3.1018 - mean_absolute_error: 1.1158
# Epoch 364/500
# 800/800 [==============================] - 0s 91us/step - loss: 3.1965 - mean_absolute_error: 1.1463
# Epoch 365/500
# 800/800 [==============================] - 0s 115us/step - loss: 3.2933 - mean_absolute_error: 1.1563
# Epoch 366/500
# 800/800 [==============================] - 0s 114us/step - loss: 3.2703 - mean_absolute_error: 1.1358
# Epoch 367/500
# 800/800 [==============================] - 0s 163us/step - loss: 2.5585 - mean_absolute_error: 1.0439
# Epoch 368/500
# 800/800 [==============================] - 0s 110us/step - loss: 3.3225 - mean_absolute_error: 1.1767
# Epoch 369/500
# 800/800 [==============================] - 0s 134us/step - loss: 2.7744 - mean_absolute_error: 1.1560
# Epoch 370/500
# 800/800 [==============================] - 0s 105us/step - loss: 2.8650 - mean_absolute_error: 1.0942
# Epoch 371/500
# 800/800 [==============================] - 0s 119us/step - loss: 2.9090 - mean_absolute_error: 1.1003
# Epoch 372/500
# 800/800 [==============================] - 0s 114us/step - loss: 2.7554 - mean_absolute_error: 1.1658
# Epoch 373/500
# 800/800 [==============================] - 0s 141us/step - loss: 3.0331 - mean_absolute_error: 1.0748
# Epoch 374/500
# 800/800 [==============================] - 0s 123us/step - loss: 2.8093 - mean_absolute_error: 1.1578
# Epoch 375/500
# 800/800 [==============================] - 0s 114us/step - loss: 2.8393 - mean_absolute_error: 1.1251
# Epoch 376/500
# 800/800 [==============================] - 0s 105us/step - loss: 2.9331 - mean_absolute_error: 1.0996
# Epoch 377/500
# 800/800 [==============================] - 0s 111us/step - loss: 2.9394 - mean_absolute_error: 1.1094
# Epoch 378/500
# 800/800 [==============================] - 0s 95us/step - loss: 2.8992 - mean_absolute_error: 1.0850
# Epoch 379/500
# 800/800 [==============================] - 0s 93us/step - loss: 2.7865 - mean_absolute_error: 1.0760
# Epoch 380/500
# 800/800 [==============================] - 0s 99us/step - loss: 3.3134 - mean_absolute_error: 1.2394
# Epoch 381/500
# 800/800 [==============================] - 0s 91us/step - loss: 2.5955 - mean_absolute_error: 1.0568
# Epoch 382/500
# 800/800 [==============================] - 0s 95us/step - loss: 3.1374 - mean_absolute_error: 1.1655
# Epoch 383/500
# 800/800 [==============================] - 0s 90us/step - loss: 2.8382 - mean_absolute_error: 1.1688
# Epoch 384/500
# 800/800 [==============================] - 0s 96us/step - loss: 2.9007 - mean_absolute_error: 1.0836
# Epoch 385/500
# 800/800 [==============================] - 0s 96us/step - loss: 3.4152 - mean_absolute_error: 1.1563
# Epoch 386/500
# 800/800 [==============================] - 0s 101us/step - loss: 2.3071 - mean_absolute_error: 0.9928
# Epoch 387/500
# 800/800 [==============================] - 0s 100us/step - loss: 2.7806 - mean_absolute_error: 1.0989
# Epoch 388/500
# 800/800 [==============================] - 0s 105us/step - loss: 2.7272 - mean_absolute_error: 1.0393
# Epoch 389/500
# 800/800 [==============================] - 0s 89us/step - loss: 2.7920 - mean_absolute_error: 1.0614
# Epoch 390/500
# 800/800 [==============================] - 0s 95us/step - loss: 3.0688 - mean_absolute_error: 1.0757
# Epoch 391/500
# 800/800 [==============================] - 0s 119us/step - loss: 3.0434 - mean_absolute_error: 1.0444
# Epoch 392/500
# 800/800 [==============================] - 0s 157us/step - loss: 2.2471 - mean_absolute_error: 1.0750
# Epoch 393/500
# 800/800 [==============================] - 0s 154us/step - loss: 3.7334 - mean_absolute_error: 1.1859
# Epoch 394/500
# 800/800 [==============================] - 0s 118us/step - loss: 2.4609 - mean_absolute_error: 1.0150
# Epoch 395/500
# 800/800 [==============================] - 0s 121us/step - loss: 2.9573 - mean_absolute_error: 1.0798
# Epoch 396/500
# 800/800 [==============================] - 0s 141us/step - loss: 2.8563 - mean_absolute_error: 1.1222
# Epoch 397/500
# 800/800 [==============================] - 0s 166us/step - loss: 2.7257 - mean_absolute_error: 1.0318
# Epoch 398/500
# 800/800 [==============================] - 0s 172us/step - loss: 3.0242 - mean_absolute_error: 1.0667
# Epoch 399/500
# 800/800 [==============================] - ETA: 0s - loss: 2.6869 - mean_absolute_error: 1.103 - 0s 180us/step - loss: 2.4906 - mean_absolute_error: 1.0837
# Epoch 400/500
# 800/800 [==============================] - 0s 96us/step - loss: 3.0731 - mean_absolute_error: 1.2004
# Epoch 401/500
# 800/800 [==============================] - 0s 96us/step - loss: 2.8654 - mean_absolute_error: 1.1114
# Epoch 402/500
# 800/800 [==============================] - 0s 102us/step - loss: 2.4629 - mean_absolute_error: 1.0480
# Epoch 403/500
# 800/800 [==============================] - 0s 98us/step - loss: 2.8467 - mean_absolute_error: 1.1049
# Epoch 404/500
# 800/800 [==============================] - 0s 95us/step - loss: 2.6413 - mean_absolute_error: 1.0502
# Epoch 405/500
# 800/800 [==============================] - 0s 99us/step - loss: 2.7417 - mean_absolute_error: 1.0921
# Epoch 406/500
# 800/800 [==============================] - 0s 90us/step - loss: 2.8192 - mean_absolute_error: 1.1065
# Epoch 407/500
# 800/800 [==============================] - 0s 89us/step - loss: 3.0189 - mean_absolute_error: 1.1111
# Epoch 408/500
# 800/800 [==============================] - 0s 112us/step - loss: 2.9824 - mean_absolute_error: 1.0237
# Epoch 409/500
# 800/800 [==============================] - 0s 100us/step - loss: 2.3655 - mean_absolute_error: 0.9791
# Epoch 410/500
# 800/800 [==============================] - 0s 111us/step - loss: 2.4031 - mean_absolute_error: 1.0007
# Epoch 411/500
# 800/800 [==============================] - 0s 97us/step - loss: 2.9648 - mean_absolute_error: 1.1135
# Epoch 412/500
# 800/800 [==============================] - 0s 99us/step - loss: 2.7005 - mean_absolute_error: 1.0645
# Epoch 413/500
# 800/800 [==============================] - 0s 186us/step - loss: 2.6706 - mean_absolute_error: 1.0580
# Epoch 414/500
# 800/800 [==============================] - 0s 157us/step - loss: 2.4869 - mean_absolute_error: 1.0347
# Epoch 415/500
# 800/800 [==============================] - 0s 130us/step - loss: 2.8425 - mean_absolute_error: 1.1190
# Epoch 416/500
# 800/800 [==============================] - 0s 141us/step - loss: 2.7192 - mean_absolute_error: 1.0953
# Epoch 417/500
# 800/800 [==============================] - 0s 106us/step - loss: 2.7616 - mean_absolute_error: 1.1164
# Epoch 418/500
# 800/800 [==============================] - 0s 98us/step - loss: 2.5769 - mean_absolute_error: 1.0284
# Epoch 419/500
# 800/800 [==============================] - 0s 94us/step - loss: 3.1958 - mean_absolute_error: 1.1251
# Epoch 420/500
# 800/800 [==============================] - 0s 95us/step - loss: 2.6158 - mean_absolute_error: 1.0733
# Epoch 421/500
# 800/800 [==============================] - 0s 151us/step - loss: 2.7471 - mean_absolute_error: 1.0690
# Epoch 422/500
# 800/800 [==============================] - 0s 158us/step - loss: 2.6914 - mean_absolute_error: 1.1075
# Epoch 423/500
# 800/800 [==============================] - 0s 122us/step - loss: 2.5904 - mean_absolute_error: 1.0173
# Epoch 424/500
# 800/800 [==============================] - 0s 111us/step - loss: 3.3922 - mean_absolute_error: 1.1144
# Epoch 425/500
# 800/800 [==============================] - 0s 149us/step - loss: 2.1552 - mean_absolute_error: 0.9407
# Epoch 426/500
# 800/800 [==============================] - 0s 130us/step - loss: 2.0998 - mean_absolute_error: 0.9740
# Epoch 427/500
# 800/800 [==============================] - 0s 139us/step - loss: 3.1027 - mean_absolute_error: 1.0913
# Epoch 428/500
# 800/800 [==============================] - 0s 124us/step - loss: 2.4984 - mean_absolute_error: 0.9697
# Epoch 429/500
# 800/800 [==============================] - 0s 104us/step - loss: 2.9459 - mean_absolute_error: 1.1258
# Epoch 430/500
# 800/800 [==============================] - 0s 207us/step - loss: 2.7450 - mean_absolute_error: 1.0539
# Epoch 431/500
# 800/800 [==============================] - 0s 188us/step - loss: 2.4504 - mean_absolute_error: 1.0112
# Epoch 432/500
# 800/800 [==============================] - 0s 184us/step - loss: 2.9009 - mean_absolute_error: 1.0368
# Epoch 433/500
# 800/800 [==============================] - 0s 170us/step - loss: 2.6497 - mean_absolute_error: 0.9405
# Epoch 434/500
# 800/800 [==============================] - 0s 95us/step - loss: 2.3362 - mean_absolute_error: 1.0017
# Epoch 435/500
# 800/800 [==============================] - 0s 101us/step - loss: 2.7122 - mean_absolute_error: 1.0528
# Epoch 436/500
# 800/800 [==============================] - 0s 98us/step - loss: 2.7165 - mean_absolute_error: 0.9816
# Epoch 437/500
# 800/800 [==============================] - 0s 101us/step - loss: 2.8488 - mean_absolute_error: 0.9622
# Epoch 438/500
# 800/800 [==============================] - 0s 92us/step - loss: 2.2563 - mean_absolute_error: 0.9599
# Epoch 439/500
# 800/800 [==============================] - 0s 91us/step - loss: 3.0176 - mean_absolute_error: 1.0893
# Epoch 440/500
# 800/800 [==============================] - 0s 84us/step - loss: 2.7143 - mean_absolute_error: 1.0320
# Epoch 441/500
# 800/800 [==============================] - 0s 85us/step - loss: 2.4339 - mean_absolute_error: 0.9871
# Epoch 442/500
# 800/800 [==============================] - 0s 95us/step - loss: 2.5740 - mean_absolute_error: 1.0665
# Epoch 443/500
# 800/800 [==============================] - 0s 90us/step - loss: 3.2250 - mean_absolute_error: 1.1580
# Epoch 444/500
# 800/800 [==============================] - 0s 86us/step - loss: 2.3712 - mean_absolute_error: 0.9319
# Epoch 445/500
# 800/800 [==============================] - 0s 155us/step - loss: 2.4564 - mean_absolute_error: 0.9969
# Epoch 446/500
# 800/800 [==============================] - 0s 127us/step - loss: 2.5048 - mean_absolute_error: 1.0159
# Epoch 447/500
# 800/800 [==============================] - 0s 142us/step - loss: 2.6524 - mean_absolute_error: 1.1101
# Epoch 448/500
# 800/800 [==============================] - 0s 149us/step - loss: 2.8566 - mean_absolute_error: 1.0406
# Epoch 449/500
# 800/800 [==============================] - 0s 114us/step - loss: 2.4914 - mean_absolute_error: 1.0422
# Epoch 450/500
# 800/800 [==============================] - 0s 106us/step - loss: 2.8017 - mean_absolute_error: 1.0926
# Epoch 451/500
# 800/800 [==============================] - 0s 90us/step - loss: 2.6608 - mean_absolute_error: 0.9494
# Epoch 452/500
# 800/800 [==============================] - 0s 86us/step - loss: 2.6358 - mean_absolute_error: 1.0079
# Epoch 453/500
# 800/800 [==============================] - 0s 186us/step - loss: 2.2843 - mean_absolute_error: 0.9602
# Epoch 454/500
# 800/800 [==============================] - 0s 144us/step - loss: 2.6304 - mean_absolute_error: 1.0070
# Epoch 455/500
# 800/800 [==============================] - 0s 132us/step - loss: 2.6985 - mean_absolute_error: 0.9759
# Epoch 456/500
# 800/800 [==============================] - 0s 117us/step - loss: 2.1508 - mean_absolute_error: 0.9312
# Epoch 457/500
# 800/800 [==============================] - 0s 85us/step - loss: 2.6954 - mean_absolute_error: 1.0619
# Epoch 458/500
# 800/800 [==============================] - 0s 89us/step - loss: 2.3093 - mean_absolute_error: 1.0369
# Epoch 459/500
# 800/800 [==============================] - 0s 90us/step - loss: 2.5798 - mean_absolute_error: 0.9313
# Epoch 460/500
# 800/800 [==============================] - 0s 91us/step - loss: 2.7608 - mean_absolute_error: 0.9845
# Epoch 461/500
# 800/800 [==============================] - 0s 91us/step - loss: 2.6751 - mean_absolute_error: 1.0027
# Epoch 462/500
# 800/800 [==============================] - 0s 85us/step - loss: 2.3729 - mean_absolute_error: 0.9817
# Epoch 463/500
# 800/800 [==============================] - 0s 96us/step - loss: 2.5608 - mean_absolute_error: 1.0585
# Epoch 464/500
# 800/800 [==============================] - 0s 92us/step - loss: 2.1574 - mean_absolute_error: 0.9426
# Epoch 465/500
# 800/800 [==============================] - 0s 98us/step - loss: 2.5230 - mean_absolute_error: 1.0596
# Epoch 466/500
# 800/800 [==============================] - 0s 119us/step - loss: 2.7697 - mean_absolute_error: 1.0518
# Epoch 467/500
# 800/800 [==============================] - 0s 116us/step - loss: 2.2643 - mean_absolute_error: 0.9654
# Epoch 468/500
# 800/800 [==============================] - 0s 105us/step - loss: 2.6137 - mean_absolute_error: 1.0679
# Epoch 469/500
# 800/800 [==============================] - 0s 167us/step - loss: 2.2915 - mean_absolute_error: 0.9581 0s - loss: 2.5922 - mean_absolute_error: 1.03
# Epoch 470/500
# 800/800 [==============================] - 0s 168us/step - loss: 2.5824 - mean_absolute_error: 0.9994
# Epoch 471/500
# 800/800 [==============================] - ETA: 0s - loss: 2.6056 - mean_absolute_error: 1.040 - 0s 122us/step - loss: 2.3874 - mean_absolute_error: 0.9993
# Epoch 472/500
# 800/800 [==============================] - 0s 101us/step - loss: 2.8003 - mean_absolute_error: 1.0252
# Epoch 473/500
# 800/800 [==============================] - 0s 104us/step - loss: 2.1706 - mean_absolute_error: 1.0212
# Epoch 474/500
# 800/800 [==============================] - 0s 113us/step - loss: 2.4042 - mean_absolute_error: 0.9817
# Epoch 475/500
# 800/800 [==============================] - 0s 89us/step - loss: 2.2532 - mean_absolute_error: 0.9107
# Epoch 476/500
# 800/800 [==============================] - 0s 81us/step - loss: 2.0697 - mean_absolute_error: 0.9565
# Epoch 477/500
# 800/800 [==============================] - 0s 82us/step - loss: 2.3308 - mean_absolute_error: 0.9767
# Epoch 478/500
# 800/800 [==============================] - 0s 111us/step - loss: 2.4101 - mean_absolute_error: 1.0770
# Epoch 479/500
# 800/800 [==============================] - 0s 206us/step - loss: 2.3717 - mean_absolute_error: 0.9838
# Epoch 480/500
# 800/800 [==============================] - 0s 146us/step - loss: 2.4154 - mean_absolute_error: 0.9681
# Epoch 481/500
# 800/800 [==============================] - 0s 109us/step - loss: 2.1909 - mean_absolute_error: 0.9519
# Epoch 482/500
# 800/800 [==============================] - 0s 127us/step - loss: 2.5646 - mean_absolute_error: 1.0582
# Epoch 483/500
# 800/800 [==============================] - 0s 108us/step - loss: 2.6675 - mean_absolute_error: 0.9925
# Epoch 484/500
# 800/800 [==============================] - 0s 94us/step - loss: 2.3179 - mean_absolute_error: 0.9994
# Epoch 485/500
# 800/800 [==============================] - 0s 94us/step - loss: 2.1905 - mean_absolute_error: 0.9813
# Epoch 486/500
# 800/800 [==============================] - 0s 141us/step - loss: 2.5082 - mean_absolute_error: 0.9556
# Epoch 487/500
# 800/800 [==============================] - 0s 211us/step - loss: 2.6524 - mean_absolute_error: 1.0915
# Epoch 488/500
# 800/800 [==============================] - 0s 120us/step - loss: 2.4222 - mean_absolute_error: 0.9685
# Epoch 489/500
# 800/800 [==============================] - 0s 125us/step - loss: 2.5231 - mean_absolute_error: 0.9968
# Epoch 490/500
# 800/800 [==============================] - 0s 112us/step - loss: 2.2730 - mean_absolute_error: 0.9694
# Epoch 491/500
# 800/800 [==============================] - 0s 87us/step - loss: 2.1877 - mean_absolute_error: 0.9482
# Epoch 492/500
# 800/800 [==============================] - 0s 89us/step - loss: 2.5393 - mean_absolute_error: 1.0181
# Epoch 493/500
# 800/800 [==============================] - 0s 95us/step - loss: 2.2939 - mean_absolute_error: 0.9479
# Epoch 494/500
# 800/800 [==============================] - 0s 101us/step - loss: 2.2500 - mean_absolute_error: 0.9406
# Epoch 495/500
# 800/800 [==============================] - 0s 87us/step - loss: 2.5515 - mean_absolute_error: 0.8970
# Epoch 496/500
# 800/800 [==============================] - 0s 89us/step - loss: 2.5418 - mean_absolute_error: 0.8960
# Epoch 497/500
# 800/800 [==============================] - 0s 89us/step - loss: 2.3230 - mean_absolute_error: 1.0106
# Epoch 498/500
# 800/800 [==============================] - 0s 89us/step - loss: 2.8712 - mean_absolute_error: 1.0464
# Epoch 499/500
# 800/800 [==============================] - 0s 95us/step - loss: 2.3268 - mean_absolute_error: 0.9853
# Epoch 500/500
# 800/800 [==============================] - 0s 93us/step - loss: 2.3794 - mean_absolute_error: 0.8756
# 200/200 [==============================] - 0s 535us/step
# Score: [0.5252578926086425, 0.6216431617736816]

# %% [markdown]
# The best score is within a meter from the projectile formula, just to make sure let's check results from the model with the actual formula (your results may vary as dataset generation for model training is random):

# %%
angle = 45
speed = 30
prediction = model.predict(np.array([(speed,angle)]))
actual = speed**2*np.sin(np.deg2rad(2*angle)) / g
print(f"{speed}/{angle} prediction: {prediction} actual: {actual}")
# Out:
# 30/45 prediction: [[91.18884]] actual: 91.74311926605505

# %% [markdown]
# Angular Motion
# ==============
#
# Angular movement is common in sports and can be described using the same dynamics principles we discussed earlier.
#
# Angular First Law (Law of Inertia)
# ----------------------------------
#
# Similarly to the first law for linear motion, the law of inertia can be applied to rotational systems, but instead of linear velocity, we refer to angular velocity, and force is torque in rotational terms. In angular motion, momentum relates to the angular momentum:
#
# $$angular\ momentum = moment\ of\ inertia*angular\ velocity$$
#
# $$L = I\omega$$
#
# Every object moves with a constant angular velocity unless acted upon by a torque.
#
# Angular Second Law
# -------------------
#
# Newton's second law of rotation is called the law of rotational dynamics. It states that angular acceleration is proportional to net torque and inversely proportional to moment of inertia:
#
# $$torque = moment\ of\ inertia*angular\ acceleration$$
#
# $$\tau = I\alpha$$
#
# Angular Third Law
# -----------------
#
# For every applied torque, there's an equal and opposite torque. For example, for a figure skater gravitational force creates torque towards the ice, but that also means that the ice provides an opposite torque pointing in the opposite direction.
#
# Conservation Laws
# -----------------
#
# In physics momentum conservation laws state that *in a closed system momentum doesn't change over time*. This applies to both linear and angular momentum discussed earlier. In sports conservation laws are used in many typed of activities, for example in figure skating.
#
# A spinning figure skater mechanically is a nearly closed system. The contact that the skater maintains with the ice has friction that is negligibly small and rotation happens around the pivot point. Her angular momentum is conserved, because there's no torque acting on her. The rotational first law (law of inertia) states that angular momentum remains constant:
#
# $$L = I\omega$$
#
# To accelerate, the skater can pull her arms, the moment of inertia $L$ will decrease, and angular velocity $\omega$, therefore will increase. When she's extending her arms and leg, the moment of inertia $L$ increases, this results in decrease of $\text{Iω}$, so she slows down. How much does she accelerate when she pulls her arms and legs out? Let's estimate her moment of inertia with arms and leg in and out, and also increase in angular velocity. Assuming the skater weighs 50 kg and making some assumptions about body parts weight and proportions (radius) of her torso, and length of arms and leg, it's easy to calculate momentum. I used cylinder as an approximation for the athlete's body:

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

g = 9.81 # m/s^2

m_body = 55 # kg
m_torso = 0.5 * m_body # kg
m_arm = 0.06 * m_body # kg
print(f"m_arm: {m_arm:.2f}kg\nm_torso: {m_torso:.1f}kg")

r_torso = 0.25 # m
r_arm = 0.7 # m

MOI_torso = (1./2.) * m_torso * r_torso**2
MOI_arm = (1./3.) * m_arm * r_arm**2
print(f"Moment of inertia (arm): {MOI_arm:.3f}kg*m^2")
print(f"Moment of inertia (torso): {MOI_torso:.3f}kg*m^2")

MOI_1 = MOI_arm*2 + MOI_torso
MOI_2 = MOI_torso
print(f"Moment of inertia (out): {MOI_1:.3f}kg*m^2")
print(f"Moment of inertia (in): {MOI_2:.3f}kg*m^2")

w1 = 2 # revolutions per second

w2 = w1 * MOI_1 / MOI_2

print(f"Spin rate In: {w1:.0f} Out:  {w2:.0f} rev/sec")
# Out:
# m_arm: 3.30kg
# m_torso: 27.5kg
# Moment of inertia (arm): 0.539kg*m^2
# Moment of inertia (torso): 0.859kg*m^2
# Moment of inertia (out): 1.937kg*m^2
# Moment of inertia (in): 0.859kg*m^2
# Spin rate In: 2 Out:  5 rev/sec

# %% [markdown]
# Energy, Work and Power
# ======================
#
# The ability to do work is called energy, another key physics concept we use in sports. Biomechanics is using several forms of energy that mechanics defines: kinetical energy as the energy resulting from motion, potential energy due to position as a result of gravitational force (for example, a skier stranding on the top of the run), or strain energy (a form of potential energy stored due to elastic properties of materials). Any moving object has kinetic energy due to its motion:
#
# $$K = \ \frac{mv^{2}}{2}$$
#
# Potential energy, due to gravitational force is defined by acceleration due to gravity *g* (9.81 m/s\^2) and *h* (height):
#
# $$P = \ mgh$$
#
# Elastic potential energy is due to deformation and can easily be explained by looking at a tennis racquet: the tension of the strings impacts the serve. The stiffness is defined by constant *k*, and the amount of deformation is $\mathrm{\Delta}x$:
#
# $$E = \ \frac{k{\mathrm{\Delta}x}^{2}}{2}$$
#
# Now, we can also introduce the physical concept of work:
#
# $work = force*distance$
#
# $W = Fs$
#
# The unit of work is joules and it's equal to energy transferred to an object when the force of one newton acts on it through a distance of one meter.

# %% [markdown]
# Physics and Deep Learning
# =========================
#
# > Geometrical ideas correspond to more or less exact objects in nature and these last are undoubtedly the exclusive cause of the genesis of those ideas.
# >
# > Albert Einstein, Theory of Relativity
#
#
#
# Machine learning uses observations (training data) as the input, and the output is generating the rules (weights of the model). Do you see where I'm getting to? In biomechanics we use existing rules, while our machine learning model may not necessarily be aware of the laws of physics, but it learns rules from observations! From training each epoch, our model learns what Newton, perhaps, learned by observing his apple falling. Our knowledge of physics comes very handy when we need to build and train models, for example during validation.
#
# Models
# ------
#
# A physical model typically includes several *parameters*. How many? Depends on the model, but we typically deal with time, acceleration, mass etc. Let's say, physical models typically have *several* parameters. A machine learning model has millions of parameters. To illustrate my point, with principal component analysis (PCA) a model we built to classify movements of a beginner skier compared with an advanced skier, resulted in several thousand features that significantly contributed to the movement. When a human coach looks at a skier, he can do that classification immediately, but it's not because of biomechanical model he's using in his head! Just to give you a practical example, video recognition model we use in Chapter 9, "Video Action Recognition" has 31 million parameters! In fact, it's easy to count parameters with this code snippet. I'm using PyTorch here, but similarly you can do with other frameworks (see Chapter 3, "Sports Scientist Toolbox"):

# %%
import torch
import torchvision
import torchvision.models as models

model = models.video.r2plus1d_18(pretrained=True)
model.eval()

params_total = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'Parameters: {params_total}')
# Out:
# Parameters: 31505325

# %% [markdown]
# Of course, no human sport analyst would use so many parameters when creating a biomechanical model! The whole point of using physics here, is that a physical model implies a lot of knowledge we have about movement and greatly simplifies understanding. AI has often been criticized as being a "black box", and rightfully so: $F = ma$ is a lot easier to understand than a Numpy array of weights in the model!
#
# **Interesting fact**: machine learning models, for example for movement classification work just like your brain, and that is without knowing biomechanics at all! But physics stores a lot of knowledge we can use in our models.
#
# Coach knows how to quickly classify a beginner from an expert. A professional ski instructor is used to identify ten levels of skiers for a teaching progression, but it becomes harder as you get into the level of Lindsey Vonn and Mikaela Shiffrin to do movement analysis using the standard teaching scale. This is why Olympic level coaches are hard to find! Machine learning is also great at what human brain is good at: classifying movements, given the right amount of data it can do it at any level of sport action.
#
# Mechanics and Reinforcement Learning
# ====================================
#
# Reinforcement Learning has been a hot area in deep learning research. As sport scientists we cannot bypass frameworks with the name like OpenAI Gym with our attention: it sounds so close to applied field of sports that we should give it a shot. In Reinforcement Learning (RL) the idea that you can train the model by giving an agent a reward sounds like a great idea to apply to sports.
#
# ![](images/ch2/fig_2-10.PNG)
#
# In fact, reinforcement learning has many methods, including Q-learning, Actor-Critic (A2C). The fact that reinforcement learning can also solve continuous problems, like predicting velocity, displacement and other measure sounds especially interesting. Previously in this chapter we used a neural net with linear regressor to predict a projectile, now we'll use reinforcement learning for problems that often happen in sports like skateboarding, snowboarding, surfing and skiing.
#
# Project: Starting with Reinforcement Learning for Skateboarding
#
# ![](images/ch2/fig_2-11.PNG)
#
# In sports like skateboarding, surfing and skiing there's often a need for an athlete to gain altitude, increasing gravitational potential energy for the next maneuver and gain kinetic energy. Think of a half-pipe for example: in half-pipe which is common in skateboarding, snowboarding and skiing athletes use physics of angular impulse and momentum we discussed earlier in this chapter to continuously move along the half-pipe and even perform tricks in the air outside of the half-pipe. The walls of half-pipe are relatively short, but the athlete can move along the half-pipe by continuously move up and down the walls.
#
# Similar idea is with surfing: one of the first skills surfers learn is moving up-and down the face of the wave to move along the wave rather than straight down to shore. This provides room to countless surfing maneuvers, like cutbacks and air and increases the distance surfers travel: in fact, according to Guinness World Records book, the longest surf ride was 10.6 miles (https://www.guinnessworldrecords.com/world-records/longest-surfing-ride-on-a-river-bore/)! The face of the wave was up-to 8 ft at the highest, yet because the surfer was moving up and down the face of the wave he was able to have the longest ride!
#
# Back to reinforcement learning, OpenAI Gym provides convenient environments specific to problems they are solving. You can always check the latest registry of available environments with:

# %%
import gym
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

print(gym.envs.registry.all())
# Out:
# dict_values([EnvSpec(Copy-v0), EnvSpec(RepeatCopy-v0), EnvSpec(ReversedAddition-v0), EnvSpec(ReversedAddition3-v0), EnvSpec(DuplicatedInput-v0), EnvSpec(Reverse-v0), EnvSpec(CartPole-v0), EnvSpec(CartPole-v1), EnvSpec(MountainCar-v0), EnvSpec(MountainCarContinuous-v0), EnvSpec(Pendulum-v0), EnvSpec(Acrobot-v1), EnvSpec(LunarLander-v2), EnvSpec(LunarLanderContinuous-v2), EnvSpec(BipedalWalker-v2), EnvSpec(BipedalWalkerHardcore-v2), EnvSpec(CarRacing-v0), EnvSpec(Blackjack-v0), EnvSpec(KellyCoinflip-v0), EnvSpec(KellyCoinflipGeneralized-v0), EnvSpec(FrozenLake-v0), EnvSpec(FrozenLake8x8-v0), EnvSpec(CliffWalking-v0), EnvSpec(NChain-v0), EnvSpec(Roulette-v0), EnvSpec(Taxi-v3), EnvSpec(GuessingGame-v0), EnvSpec(HotterColder-v0), EnvSpec(Reacher-v2), EnvSpec(Pusher-v2), EnvSpec(Thrower-v2), EnvSpec(Striker-v2), EnvSpec(InvertedPendulum-v2), EnvSpec(InvertedDoublePendulum-v2), EnvSpec(HalfCheetah-v2), EnvSpec(HalfCheetah-v3), EnvSpec(Hopper-v2), EnvSpec(Hopper-v3), EnvSpec(Swimmer-v2), EnvSpec(Swimmer-v3), EnvSpec(Walker2d-v2), EnvSpec(Walker2d-v3), EnvSpec(Ant-v2), EnvSpec(Ant-v3), EnvSpec(Humanoid-v2), EnvSpec(Humanoid-v3), EnvSpec(HumanoidStandup-v2), EnvSpec(FetchSlide-v1), EnvSpec(FetchPickAndPlace-v1), EnvSpec(FetchReach-v1), EnvSpec(FetchPush-v1), EnvSpec(HandReach-v0), EnvSpec(HandManipulateBlockRotateZ-v0), EnvSpec(HandManipulateBlockRotateZTouchSensors-v0), EnvSpec(HandManipulateBlockRotateZTouchSensors-v1), EnvSpec(HandManipulateBlockRotateParallel-v0), EnvSpec(HandManipulateBlockRotateParallelTouchSensors-v0), EnvSpec(HandManipulateBlockRotateParallelTouchSensors-v1), EnvSpec(HandManipulateBlockRotateXYZ-v0), EnvSpec(HandManipulateBlockRotateXYZTouchSensors-v0), EnvSpec(HandManipulateBlockRotateXYZTouchSensors-v1), EnvSpec(HandManipulateBlockFull-v0), EnvSpec(HandManipulateBlock-v0), EnvSpec(HandManipulateBlockTouchSensors-v0), EnvSpec(HandManipulateBlockTouchSensors-v1), EnvSpec(HandManipulateEggRotate-v0), EnvSpec(HandManipulateEggRotateTouchSensors-v0), EnvSpec(HandManipulateEggRotateTouchSensors-v1), EnvSpec(HandManipulateEggFull-v0), EnvSpec(HandManipulateEgg-v0), EnvSpec(HandManipulateEggTouchSensors-v0), EnvSpec(HandManipulateEggTouchSensors-v1), EnvSpec(HandManipulatePenRotate-v0), EnvSpec(HandManipulatePenRotateTouchSensors-v0), EnvSpec(HandManipulatePenRotateTouchSensors-v1), EnvSpec(HandManipulatePenFull-v0), EnvSpec(HandManipulatePen-v0), EnvSpec(HandManipulatePenTouchSensors-v0), EnvSpec(HandManipulatePenTouchSensors-v1), EnvSpec(FetchSlideDense-v1), EnvSpec(FetchPickAndPlaceDense-v1), EnvSpec(FetchReachDense-v1), EnvSpec(FetchPushDense-v1), EnvSpec(HandReachDense-v0), EnvSpec(HandManipulateBlockRotateZDense-v0), EnvSpec(HandManipulateBlockRotateZTouchSensorsDense-v0), EnvSpec(HandManipulateBlockRotateZTouchSensorsDense-v1), EnvSpec(HandManipulateBlockRotateParallelDense-v0), EnvSpec(HandManipulateBlockRotateParallelTouchSensorsDense-v0), EnvSpec(HandManipulateBlockRotateParallelTouchSensorsDense-v1), EnvSpec(HandManipulateBlockRotateXYZDense-v0), EnvSpec(HandManipulateBlockRotateXYZTouchSensorsDense-v0), EnvSpec(HandManipulateBlockRotateXYZTouchSensorsDense-v1), EnvSpec(HandManipulateBlockFullDense-v0), EnvSpec(HandManipulateBlockDense-v0), EnvSpec(HandManipulateBlockTouchSensorsDense-v0), EnvSpec(HandManipulateBlockTouchSensorsDense-v1), EnvSpec(HandManipulateEggRotateDense-v0), EnvSpec(HandManipulateEggRotateTouchSensorsDense-v0), EnvSpec(HandManipulateEggRotateTouchSensorsDense-v1), EnvSpec(HandManipulateEggFullDense-v0), EnvSpec(HandManipulateEggDense-v0), EnvSpec(HandManipulateEggTouchSensorsDense-v0), EnvSpec(HandManipulateEggTouchSensorsDense-v1), EnvSpec(HandManipulatePenRotateDense-v0), EnvSpec(HandManipulatePenRotateTouchSensorsDense-v0), EnvSpec(HandManipulatePenRotateTouchSensorsDense-v1), EnvSpec(HandManipulatePenFullDense-v0), EnvSpec(HandManipulatePenDense-v0), EnvSpec(HandManipulatePenTouchSensorsDense-v0), EnvSpec(HandManipulatePenTouchSensorsDense-v1), EnvSpec(Adventure-v0), EnvSpec(Advent ...

# %% [markdown]
# For applications in skateboarding, snowboarding, surfing and skiing, gym environments in classic control area are especially interesting, specifically let's focus on MountainCarContinuous environment that solves a very similar problem! The following code creates the environment and creates a visualization of the problem:

# %%
from IPython import display
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

env = gym.make('MountainCarContinuous-v0')
env.reset()
plt.figure(figsize=(9,9))
img = plt.imshow(env.render(mode='rgb_array')) # only call this once
for _ in range(100):
    img.set_data(env.render(mode='rgb_array')) # just update the data
    display.display(plt.gcf())
    display.clear_output(wait=True)
    action = env.action_space.sample()
    env.step(action)
env.close()

# %% [markdown]
# The MountainCarContinuous environment provides an out-of-the-box model of a car that needs to use the momentum to get on top of the hill. That is very similar to what a skateboarder needs to do in order to skate to the top of the half-pipe wall. The difference is that the built-in environment includes the notion of power (that is the car is said to be underpowered, but still powered), obviously our skateboarder needs to use his body to create the momentum. In skateboarding, surfing and other sports this is often called 'pumping', by crouching down and then extending, the athlete is able to increase his velocity. For the purpose of our exercise, we can say that the ability to 'pump' provides a mechanical equivalent of the engine. In the following chapters I will show how to train a model that uses Reinforcement Learning to solve the problem of half-pipe.
#
# Summary
# =======
#
# Physics principles describe motion and provide an analytical foundation for biomechanics, the science that studies human movement. In this chapter we had an overview of classical mechanics: kinetics and kinematics to analyze movement in sports, including linear and angular laws of motion, potential and kinematic energy. Practical projects included in accompanying notebooks for this chapter include code for examples in kinematics of projectile movement, a machine learning model that predicts a projectile using neural networks, mechanical analysis of figure skater spinning and applications of reinforcement learning for skateboarding, snowboarding, surfing and skiing.
#
# Machine learning in practical sports is a relative newcomer, the way we teach sport science today will be changing a lot in the years to come, thanks to evolution of machine learning models, tools and accuracy that's happening in data science and the field. In order for us to build models for sports motion and movement, understanding physics principles of motion is essential.

# %% [markdown]
# ## Reference
#
# [*Video Course*](http://ai-learning.vhx.tv) Need a deep dive? Watch my [*video course*](http://ai-learning.vhx.tv) that complements this book with additional examples and video-walkthroughs.
#
# [*Web Site*](http://activefitness.ai) for research and supplemental materials.
